# %% [markdown]
# ## Setup Tweepy

# %%
import tweepy

# %%
# Créer les credentials
auth = tweepy.OAuthHandler('pBFBQTZOccFuY5wArtNxr0kjh', 'vMKbrzVoPfpRoMZalmxmBhpr7juiKKfFEYQxaw1WYZk6FUN81r')
auth.set_access_token('383179024-hY4UwVVz9kL6VMGOeeZrBGfr9dOZzVEWJoCDJ6vC', 'qYTsE0kM6iq8WqGAejq5Oe5d5zQhhtrAh50DHcQ2GR9Ve')

# %%
# Confirmer l'authentification
api = tweepy.API(auth)
api.verify_credentials()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~/opt/anaconda3/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# ...

# %%
# Vérifier que tout fonctionne
user = api.get_user(screen_name='AntoineGaboriau')

print("User details:")
print(user.name)
print(user.description)
print(user.location)

print("Last 20 Followers:")
for follower in user.followers():
    print(follower.name)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~/opt/anaconda3/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# ...

# %% [markdown]
# ## Tweeter

# %%
# Connecter l'API
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# Poster un tweet
# api.update_status("J'ai tweeté avec Tweepy")

# %% [markdown]
# ## Rassembler les tweets McKinsey

# %%
# Effectuer une recherche
for tweet in api.search_30_day(label='prod', query='McKinsey scandal'):
    print(f"{tweet.user.name}:{tweet.text}")
